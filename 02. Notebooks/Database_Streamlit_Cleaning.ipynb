# %% [markdown]
# # 01. Importing Libraries

# %%
import os
import math
import random
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy
import numpy as np
import pandas as pd
import scipy.stats as st
import re

# %% [markdown]
# # 02. Importing Data

# %%
books = pd.read_csv('../01. Data/books_with_clusters.csv')

# %% [markdown]
# # 03. Beautification of Database

# %%
books.head()
# Out:
#    book_id                                              title  \
# 0        0            The Hunger Games (The Hunger Games, #1)
# 1        1                                Pride and Prejudice
# 2        2                              To Kill a Mockingbird
# 3        3  Harry Potter and the Order of the Phoenix (Har...
# 4        4                                     The Book Thief
#
#             author  avg_rating  num_ratings  \
# 0  Suzanne Collins        4.35   10115839.0
# 1      Jane Austen        4.30    4920467.0
# 2       Harper Lee        4.26    7016855.0
# 3     J.K. Rowling        4.50    3868435.0
# 4     Markus Zusak        4.39    2935583.0
#
#                                        cover_img_url  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# ...

# %%
# retting index to be book_id
books.set_index('book_id', inplace=True)

# %%
# changing num_ratings and pages into INT
books['num_ratings'] = books['num_ratings'].astype('Int64')
books['pages'] = books['pages'].astype('Int64')

# %%
books.head()
# Out:
#                                                      title           author  \
# book_id
# 0                  The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1                                      Pride and Prejudice      Jane Austen
# 2                                    To Kill a Mockingbird       Harper Lee
# 3        Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 4                                           The Book Thief     Markus Zusak
#
#          avg_rating  num_ratings  \
# book_id
# 0              4.35     10115839
# 1              4.30      4920467
# 2              4.26      7016855
# 3              4.50      3868435
# 4              4.39      2935583
#
#                                              cover_img_url  \
# book_id
# 0        https://i.gr-assets.com/images/S/compressed.ph...
# 1        https://i.gr-assets.com/images/S/compressed.ph...
# 2        https://i.gr-assets.com/images/S/compressed.ph...
# ...

# %%
books.isnull().sum()
# Out:
# title                0
# author               0
# avg_rating         755
# num_ratings        733
# cover_img_url        4
# goodreads_url     1000
# source               0
# year_published       0
# genres               0
# description          0
# pages               24
# series            1529
# isbn              1008
# publisher         1009
# language          1004
# ol_key            1004
# google_url        1017
# cluster              0
# genres_clean         0
# dtype: int64

# %%
# stripping " " from title and author columns
books['title'] = books['title'].str.strip().str.strip('"')
books['author'] = books['author'].str.strip().str.strip('"')

# %%
# checking if books with " " in the name were stripped correctly
books[books['title'].str.contains('paint', case=False)][['title', 'genres']]
# Out:
#                             title  \
# book_id
# 1121                Painted Scars
# 1784     I Heard You Paint Houses
#
#                                                     genres
# book_id
# 1121     Romance, Dark, Contemporary Romance, Adult, Di...
# 1784                                Nonfiction, True Crime

# %%
# removing duplicated genres from genres_list
def remove_duplicate_genres(genre_list):
    seen = []
    for genre in genre_list:
        if genre not in seen:
            seen.append(genre)
    return seen

def clean_genres_string(genres_string):
    genre_list = genres_string.split(', ')
    unique_genres = remove_duplicate_genres(genre_list)
    return ', '.join(unique_genres)

books['genres_clean'] = books['genres_clean'].apply(clean_genres_string)

# %%
# checking if duplicated genres were removed correctly
books[books['author'].str.contains('Agatha Christie', case=False)][['title', 'genres_clean']]
# Out:
#                                                      title  \
# book_id
# 92                                And Then There Were None
# 215      Murder on the Orient Express (Hercule Poirot, ...
# 801       The Murder of Roger Ackroyd (Hercule Poirot, #4)
# 838                Death on the Nile (Hercule Poirot, #18)
# 1125                         The Mystery of the Blue Train
# 1126                                         Endless Night
# 1144                                     Death on the Nile
#
#                                         genres_clean
# book_id
# 92       Mystery, Classics, Fiction, Thriller, Crime
# 215      Mystery, Classics, Fiction, Crime, Thriller
# 801      Mystery, Fiction, Classics, Crime, Thriller
# 838      Mystery, Fiction, Classics, Crime, Thriller
# 1125                Crimes Against, Mystery, Fiction
# 1126                                Fiction, Mystery
# 1144                                Fiction, Mystery

# %%
# allowing me to see all the rows in the dataset
pd.set_option('display.max_rows', None)

# %%
# cell output was long, so it was clear from the notebook - next cells are works done based on the output of this cell
books[['title', 'author', 'description', 'series']]

# %%
# correcting the series column for book_id 334
books.loc[334, ['title', 'author', 'description', 'series']]
# Out:
# title                                 The Wind-Up Bird Chronicle
# author                                           Haruki Murakami
# description    Japan's most highly regarded novelist now vaul...
# series                                            ねじまき鳥クロニクル#1-3
# Name: 334, dtype: str

# %%
# changing the series
books.loc[334, 'series'] = "The Wind-Up Bird Chronicle #1-3"

# %%
books.loc[334, ['title', 'author', 'description', 'series']]
# Out:
# title                                 The Wind-Up Bird Chronicle
# author                                           Haruki Murakami
# description    Japan's most highly regarded novelist now vaul...
# series                           The Wind-Up Bird Chronicle #1-3
# Name: 334, dtype: str

# %%
# starndardizing the series column
books['series'] = books['series'].str.replace(r'(\S)#', r'\1 #', regex=True)

# %%
books.loc[642, ['title', 'author']]
# Out:
# title                    العصبي
# author    أحمد جمال الدين رمضان
# Name: 642, dtype: str

# %%
# checking the authors to be able to know what to correct in the author column
books.loc[[642, 634, 500, 476, 1462, 1649, 1650, 1677, 1681], ['title', 'author']]
# Out:
#                                                      title  \
# book_id
# 642                                                 العصبي
# 634                                            انتحار فاشل
# 500                                     زندگی مه آلود پریا
# 476                                          القرآن الكريم
# 1462                           Before the Coffee Gets Cold
# 1649                  Chto takoe iskusstvo? / What is art?
# 1650                              Great Dialogues of Plato
# 1677     Death's End (The Three-Body Problem Series Boo...
# 1681     The Dark Forest (The Three-Body Problem Series...
#
#                         author
# book_id
# 642      أحمد جمال الدين رمضان
# 634      أحمد جمال الدين رمضان
# 500           سید مرتضی مصطفوی
# 476                       الله
# 1462                      川口俊和
# 1649               Лев Толстой
# 1650                    Πλάτων
# 1677                       刘慈欣
# 1681                       刘慈欣

# %%
# correcting the autor column for roman caracters
author_corrections = {
    'أحمد جمال الدين رمضان': 'Ahmed Gamal El-Din Ramadan',
    'سید مرتضی مصطفوی': 'Seyyed Morteza Mostafavi',
    'الله': 'Anonymous',
    '川口俊和': 'Toshikazu Kawaguchi',
    'Лев Толстой': 'Leo Tolstoy',
    'Πλάττων': 'Plato',
    '刘慈欣': 'Liu Cixin',
    'Πλάτων': 'Plato'
}

books['author'] = books['author'].replace(author_corrections)

# %%
# checking if the corrections were made correctly
books.loc[[642, 634, 500, 476, 1462, 1649, 1650, 1677, 1681], ['title', 'author']]
# Out:
#                                                      title  \
# book_id
# 642                                                 العصبي
# 634                                            انتحار فاشل
# 500                                     زندگی مه آلود پریا
# 476                                          القرآن الكريم
# 1462                           Before the Coffee Gets Cold
# 1649                  Chto takoe iskusstvo? / What is art?
# 1650                              Great Dialogues of Plato
# 1677     Death's End (The Three-Body Problem Series Boo...
# 1681     The Dark Forest (The Three-Body Problem Series...
#
#                              author
# book_id
# 642      Ahmed Gamal El-Din Ramadan
# 634      Ahmed Gamal El-Din Ramadan
# 500        Seyyed Morteza Mostafavi
# 476                       Anonymous
# 1462            Toshikazu Kawaguchi
# 1649                    Leo Tolstoy
# 1650                          Plato
# 1677                      Liu Cixin
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
# checking the title to be able to know what to correct in the title column
books.loc[[7, 274, 307, 384, 461, 476, 500, 634, 642, 1058, 1120, 1125, 1234, 1333, 1508, 1635], ['title', 'author']]
# Out:
#                                                                               title  \
# book_id
# 7             J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings
# 274      [No Country for Old Men] (By: Cormac McCarthy) [published: December, 2007]
# 307                             The Lord of the Rings (The Lord of the Rings, #1-3)
# 384                                                       Midnight Sun [2008 Draft]
# 461                                                                    ’Salem’s Lot
# 476                                                                   القرآن الكريم
# 500                                                              زندگی مه آلود پریا
# 634                                                                     انتحار فاشل
# 642                                                                          العصبي
# 1058                                                             A child called "it
# ...

# %%
# correcting title columns for roman caracters and other corrections
title_corrections = {
    'J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings': 'The Hobbit and The Lord of the Rings',
    '[No Country for Old Men] (By: Cormac McCarthy) [published: December, 2007]': 'No Country for Old Men',
    'Midnight Sun [2008 Draft]': 'Midnight Sun',
    "'Salem's Lot": "Salem's Lot",
    'القرآن الكريم': 'The Holy Quran',
    'زندگی مه آلود پریا': 'Misty Life of Pariya',
    'انتحار فاشل': 'Failed Suicide',
    'العصبي': 'The Nervous One',
    'A child called "it': 'A Child Called It',
    'Die Aufzeichnungen des Malte Laurids Brigge': 'The Notebooks of Malte Laurids Brigge',
    '... Trotzdem Ja zum Leben sagen': "Man's Search for Meaning",
    'Sein und Zeit': 'Being and Time',
}

books['title'] = books['title'].replace(title_corrections)

# %%
# checking if the corrections were done
books.loc[[7, 274, 307, 384, 461, 476, 500, 634, 642, 1058, 1120, 1125, 1234, 1333, 1508, 1635], ['title', 'author']]
# Out:
#                                                        title  \
# book_id
# 7                       The Hobbit and The Lord of the Rings
# 274                                   No Country for Old Men
# 307      The Lord of the Rings (The Lord of the Rings, #1-3)
# 384                                             Midnight Sun
# 461                                             ’Salem’s Lot
# 476                                           The Holy Quran
# 500                                     Misty Life of Pariya
# 634                                           Failed Suicide
# 642                                          The Nervous One
# 1058                                       A Child Called It
# 1120                                          All She Wanted
# 1125                           The Mystery of the Blue Train
# 1234                   The Notebooks of Malte Laurids Brigge
# 1333                                Man's Search for Meaning
# ...

# %%
# titeling the title and author columns
books['title'] = books['title'].str.title()
books['author'] = books['author'].str.title()

# %%
# cleaning the description column
# removing space before opening quotes
books['description'] = books['description'].str.replace(r'\. "', '."', regex=False)

# removing "Show more" at the end
books['description'] = books['description'].str.replace(r'\s*Show more$', '', regex=True)

# spacing after commas and periods
books['description'] = books['description'].str.replace(r'([.,])(\S)', r'\1 \2', regex=True)

# removing "Alternate cover edition of..." sentences
books['description'] = books['description'].str.replace(r'Alternate cover edition of[^.]*\.?', '', regex=True)

# replacing multiple newlines with a single space
books['description'] = books['description'].str.replace(r'\r\n+', ' ', regex=True)

# cleaning html tags
books['description'] = books['description'].str.replace(r'<[^>]+>', '', regex=True)

# %%
# code used to check blocks of descriptions to be able to check if bulk were done and also what needed manual input
books.loc[2002:2003, ['title', 'author', 'year_published', 'description']]
# Out:
#                                                               title  \
# book_id
# 2002                                     The Silver Palate Cookbook
# 2003     The Deal / The Mistake / The Score / The Goal / The Legacy
#
#                              author year_published  \
# book_id
# 2002     Julee Rosso, Sheila Lukins           1982
# 2003                   Elle Kennedy           2021
#
# ...

# %%
# manual inputing in description column
books.loc[500, 'description'] = "Mystical story. The internal revolution of a woman and the fight against her past. The story follows a successful and charismatic woman who manages a large traditional inn, ranked first in attracting both Iranian and foreign guests. Although Pariya is highly talented and gifted, envied by others for her success, she once made a great mistake in her past that she does not dare reveal to anyone close to her. As the story progresses, her past slowly descends on her restless soul like a nightmare, tormenting her deeply. Falling ill intensifies her guilt, and she faces many challenges in overcoming this crisis."
books.loc[642, 'description'] = "Everyone knew he was nervous. But that was not the problem — the problem was that he admitted it. He acknowledged that he was nervous, easily provoked, and impulsive, yet he never tried to change. Anger would overtake him and he would erupt into a torrent of insults for the most trivial of reasons, sometimes for no reason at all. He would lose his temper"
books.loc[1255, 'description'] = "The Ramayana is one of the greatest Sanskrit epics of ancient India, telling the story of Rama, ideal man and incarnation of the god Vishnu. Written by the sage Valmiki, this monumental work has profoundly shaped the literature, art, religion, and culture of countless millions across South and Southeast Asia for thousands of years. The epic follows Rama's journey through exile, the abduction of his beloved wife Sita by the demon king Ravana, and the great war to rescue her with the help of the monkey hero Hanuman. This scholarly edition, translated by Robert P. Goldman, Rosalind Lefeber, and Sheldon Pollock, is based on the authoritative critical edition and includes extensive introductions, notes, and bibliography."
books.loc[1293, 'description'] = "Published in 1902, As a Man Thinketh is a timeless self-help classic by James Allen that explores the profound connection between thought and reality. Drawing on the biblical aphorism 'As a man thinketh in his heart, so is he,' Allen argues that a person is literally what they think — their character being the complete sum of all their thoughts. Through simple yet powerful insights, Allen shows how cultivating positive, disciplined thinking can transform one's character, circumstances, and destiny. A short but deeply influential work, it has guided millions of readers toward a life of purpose, clarity, and inner peace for over a century."
books.loc[1386, 'description'] = "Published in 1966, The Book: On the Taboo Against Knowing Who You Are is a philosophical masterpiece by Alan Watts that challenges the Western notion of the self as a separate ego isolated from the rest of the universe. Watts argues that this illusion of separateness is at the root of human conflict, our misuse of technology, and our destructive relationship with the natural world. Drawing on the Hindu philosophy of Vedanta, he offers a profound alternative view of personal identity — one in which the self is not separate from, but rather the root and ground of, the universe itself. Written with clarity and wit, this mind-opening book invites readers to question who they really are and to discover a deeper, more harmonious way of existing in the world."
books.loc[1765, 'description'] = "Ars Amatoria, or The Art of Love, is a witty and audacious didactic poem in three books by the ancient Roman poet Ovid, written around 2 AD. The first two books are addressed to men, offering playful and practical advice on how to find, win, and keep a woman's love — covering everything from where to meet women in Rome to how to write a flattering letter. The third book turns to women, advising them on how to attract and hold the attention of a man. Rich with humor, psychological insight, and vivid glimpses of Roman social life — the theatre, the circus, the banquet — the poem is one of the wittiest works of Latin literature. Its irreverent tone so scandalized Emperor Augustus that it was cited as one of the reasons for Ovid's eventual banishment from Rome."
books.loc[1780, 'description'] = "One L is Scott Turow's acclaimed memoir of his first year at Harvard Law School, first published in 1977 and based on a diary he kept throughout the experience. Known as a One L — the term for first-year law students — Turow takes readers inside the oldest and most prestigious law school in the country, vividly portraying the intellectual and emotional ordeal of that grueling year. From the notorious Socratic method to the crushing workload, fierce competition, and moral dilemmas that test his character, Turow captures the humiliations and triumphs of becoming a lawyer with candor and insight. A national bestseller, a law school primer, and a classic autobiography, One L is essential reading for anyone who has ever contemplated going to law school — and for anyone interested in the human cost of ambition."
books.loc[1811, 'description'] = "Entrepreneurship by Robert D. Hisrich is a leading university textbook designed to clearly instruct students on the process of formulating, planning, and implementing a new venture. Students are exposed to detailed, practical guidance on how to embark on a new business in a logical and structured manner, covering topics such as identifying opportunities, developing a business plan, securing funding, managing growth, and navigating the challenges of today's entrepreneurial landscape. Drawing on Hisrich's extensive expertise in global entrepreneurship, the book balances theory with real-world application, making it an essential resource for anyone studying or pursuing entrepreneurship."
books.loc[1812, 'description'] = "The Constitution of India, adopted on 26 November 1949 and effective from 26 January 1950, is the supreme law of India and one of the longest written constitutions in the world. It establishes the framework for the country's political system, defining the structure, powers, and duties of the government at the central and state levels. The Constitution guarantees fundamental rights to all citizens, outlines directive principles of state policy, and sets out the duties of citizens. It provides for a parliamentary form of government, an independent judiciary, and a federal structure with a strong central government. As a living document, it has been amended by Parliament numerous times to reflect the evolving needs of Indian society and governance."
books.loc[1842, 'description'] ="It was the perfect crime. . . almost.  For Salt Lake City resident and respected community member David Meade, there was only one way out of a miserable marriage and financial ruin: cold-blooded murder."
books.loc[1858, 'description'] = "Economics: An Introductory Analysis by Paul A. Samuelson and William D. Nordhaus is one of the most influential and bestselling economics textbooks ever written. First published in 1948 by Nobel Prize-winning economist Paul Samuelson, it set the gold standard for introductory economics education and introduced Keynesian macroeconomics to generations of students. Translated into 41 languages and selling over four million copies, it has appeared in nineteen editions and remains a standard-bearer in economics courses worldwide. The book covers the full spectrum of economic theory — including microeconomics, macroeconomics, supply and demand, market structures, trade, economic growth, and monetary policy — with clear explanations, compelling examples, and a commitment to helping students understand enduring economic principles and apply them to the real world."
books.loc[1865, 'description'] = "Business Law Today is a leading university textbook by Roger LeRoy Miller and Gaylord A. Jentz, designed to make business law engaging, accessible, and relevant to students. Clear, interesting, and applied, it serves as an ideal guide to the law and what it means in the business world — covering topics from contracts, secured transactions, and warranties to government regulations, intellectual property, e-commerce, and global business law. Each chapter uses real-world cases and visually engaging learning tools to illustrate how law applies to actual business problems, and how landmark statutes and court decisions shape the way businesses operate in the United States and internationally. A widely adopted textbook in business law and legal environment courses, it balances legal credibility with practical, student-friendly coverage."
books.loc[1878, 'description'] = "Microeconomic Theory: Basic Principles and Extensions by Walter Nicholson and Christopher Snyder is a market-leading textbook widely known as the bible of microeconomics for upper-level undergraduate and beginning graduate students. Taking a calculus-based approach, the book provides an ideal level of mathematical rigor while remaining accessible and practical. It covers the full spectrum of microeconomic theory — including consumer choice and demand, uncertainty, game theory, production and cost functions, competitive markets, market power, monopoly, pricing in input markets, and market failure — with clear explanations, insightful graphics, and real-world applications. Two-tier end-of-chapter problems build students' intuition progressively, from simple numerical exercises to complex analytical and behavioral economics challenges. Rigorous yet engaging, it is an essential resource for anyone studying advanced microeconomics."
books.loc[1928, 'description'] = "Planning, Implementing, and Evaluating Health Promotion Programs: A Primer by James F. McKenzie, Brad L. Neiger, and Rosemary Thackeray is the leading textbook for undergraduate courses in health education, promotion, and program planning. The first book to combine all three phases — planning, implementation, and evaluation — in one comprehensive volume, it provides students with both the practical and theoretical skills needed to develop effective health promotion programs across a variety of settings. Using a clear, step-by-step format, the book covers needs assessment, program planning models, health behavior theory, social marketing, program management, evaluation methods, and professional ethics. Updated throughout to reflect the latest national standards and Healthy People objectives, it is an essential resource for students and professionals in public health and health education."
books.loc[1931, 'description'] = "A study guide providing a comprehensive overview and analysis of Erving Goffman's foundational work on social interaction and the presentation of self in everyday life."
books.loc[1941, 'description'] = "The Power of Color: Creating Healthy Interior Spaces is the first practical guide to using full-spectrum color in interior design to support human health and well-being. Working from the scientifically based premise that color on finishes and surfaces plays a vital role in creating healthy environments, Sara O. Marberry and Laurie Zagon provide design professionals with a complete methodology and clear guidelines for designing with color without compromising style or client preferences. The book includes a concise refresher course in color theory, detailed analyses of over 20 real-world projects across healthcare facilities, schools, day-care centers, hotels, and offices, color charts breaking down proportions of hue, value, and chroma, and a showcase of over 40 full-color photographs illustrating the concepts in practice."
books.loc[1943, 'description'] = "The Social Construction of Reality: A Treatise in the Sociology of Knowledge is a landmark 1966 work by sociologists Peter L. Berger and Thomas Luckmann, voted the fifth most important sociological book of the twentieth century by the International Sociological Association. The book introduces the concept of social construction into the social sciences, arguing that reality as we experience it is not objectively given but is actively created through human interaction and habitualization. Over time, repeated patterns of interaction become institutionalized and are passed on to future generations as objective reality — a process the authors call reification. Drawing on the phenomenological tradition, Berger and Luckmann reformulate the sociology of knowledge to show how society is simultaneously a human product and an objective reality that shapes the very humans who created it. An essential text in sociology, philosophy, and social theory."
books.loc[1964, 'description'] = "Cunningham's Encyclopedia of Magical Herbs is the definitive reference guide to the magical uses of over 400 herbs and plants from around the world, written by one of the most beloved authors in modern Wicca and earth magic, Scott Cunningham. Each entry includes the herb's common and folk names, associated magical properties, ruling planet and element, and practical uses in spells, rituals, and natural magic. Illustrated for easy identification and organized for quick reference, this comprehensive encyclopedia has sold over 400,000 copies and remains an essential resource for anyone practicing natural, herbal, or folk magic."
# %%
# author check for the full data set (in blocks) to clean and take out duplicated names in the column (per row)
books.loc[1901:2003, ['title', 'author']]
# Out:
#                                                                        title  \
# book_id
# 1901                                                   Tom'S Midnight Garden
# 1902                                                     Thinking In Systems
# 1903                                               The Power Of Productivity
# 1904                                                          How Not To Die
# 1905                                             How To Make Money In Stocks
# 1906                                                               Bad Blood
# 1907                                                        Techno-Feudalism
# 1908                                         Principles Of Political Economy
# 1909                                                        Expecting Better
# 1910     The Economic Consequences Of The Peace (Twentieth-Century Classics)
# 1911                                                        The Power Of Now
# ...

# %%
# cleaning the author columns
# remove HTML non-breaking spaces
books['author'] = books['author'].str.replace(r'&nbsp;', ' ', regex=False)

# collapse multiple spaces into one
books['author'] = books['author'].str.replace(r' +', ' ', regex=True)

# strip leading/trailing spaces
books['author'] = books['author'].str.strip()

# %%
# clenaing author column after mannual review
books.loc[1031, 'author'] = "Malala Yousafzai, Christina Lamb"
books.loc[1034, 'author'] = "M. H. Abrams, Stephen Greenblatt"
books.loc[1043, 'author'] = "Charlotte Perkins Gilman"
books.loc[1060, 'author'] = "Jon Wiles, Joseph Bondi"
books.loc[1108, 'author'] = "Elizabeth Kendall"
books.loc[1133, 'author'] = "John Taylor Gatto"
books.loc[1163, 'author'] = "Martin Puchner, Suzanne Conklin Akbari, Wiebke Denecke, Barbara Fuchs, Caroline Levine, Pericles Lewis, Emily Wilson"
books.loc[1173, 'author'] = "M. David Miller, Robert L. Linn, Norman E. Gronlund"
books.loc[1199, 'author'] = "R. R. Palmer, Joel G. Colton"
books.loc[1208, 'author'] = "Winston S. Churchill"
books.loc[1209, 'author'] = "H. W. Janson, Anthony F. Janson"
books.loc[1211, 'author'] = "Jerry H. Bentley, Herbert F. Ziegler"
books.loc[1241, 'author'] = "Chancellor Williams"
books.loc[1244, 'author'] = "Anonymous"
books.loc[1250, 'author'] = "Ibn Khaldun"
books.loc[1290, 'author'] = "Robert A. Glover"
books.loc[1309, 'author'] = "James A. Banks, Cherry A. McGee Banks"
books.loc[1336, 'author'] = "Tim Grover, Shari Wenk"
books.loc[1345, 'author'] = "Fumio Sasaki"
books.loc[1351, 'author'] = "Marshall B. Rosenberg"
books.loc[1388, 'author'] = "Matthew McKay, Patrick Fanning"
books.loc[1526, 'author'] = "Thomas Paine"
books.loc[1555, 'author'] = "Mutesa II Kabaka of Buganda"
books.loc[1558, 'author'] = "Philip K. Dick"
books.loc[1559, 'author'] = "Malika Oufkir"
books.loc[1570, 'author'] = "Edward S. Herman, Noam Chomsky"
books.loc[1619, 'author'] = "Ludwig Wittgenstein"
books.loc[1620, 'author'] = "Michael Pollan"
books.loc[1663, 'author'] = "George Lakoff, Mark Johnson"
books.loc[1725, 'author'] = "Gerard J. Tortora, Bryan H. Derrickson"
books.loc[1743, 'author'] = "Robert Silverberg, Robert A. Heinlein, Arthur C. Clarke, Isaac Asimov, Ray Bradbury"
books.loc[1765, 'author'] = "Ovid, Len Krisak, Sarah Ruden"
books.loc[1778, 'author'] = "John E. Douglas, Mark Olshaker"
books.loc[1799, 'author'] = "Robert W. Mann, Miryam Williamson"
books.loc[1809, 'author'] = "John Dickie"
books.loc[1815, 'author'] = "Walter Kirn"
books.loc[1820, 'author'] = "Robert W. Newsom III, William Trotter"
books.loc[1851, 'author'] = "Walter Rodney"
books.loc[1856, 'author'] = "Thomas Aquinas"
books.loc[1857, 'author'] = "Robert S. Pindyck, Daniel L. Rubinfeld"
books.loc[1858, 'author'] = "Paul A. Samuelson, William D. Nordhaus"
books.loc[1859, 'author'] = "Kerry Patterson, Joseph Grenny, Ron McMilIan, Al Switzler"
books.loc[1863, 'author'] = "Jim Collins, Jerry I. Porras"
books.loc[1865, 'author'] = "Roger LeRoy Miller, Gaylord A. Jentz"
books.loc[1885, 'author'] = "J. C. Smith, Brian Hogan"
books.loc[1888, 'author'] = "Anonymous"
books.loc[1910, 'author'] = "John Maynard Keynes"
books.loc[1915, 'author'] = "Queen Afua"
books.loc[1931, 'author'] = "Supersummary"
books.loc[1935, 'author'] = "Linda B. White, Steven Foster"
books.loc[1936, 'author'] = "William James"
books.loc[1943, 'author'] = "Peter L. Berger, Thomas Luckmann"
books.loc[1959, 'author'] = "Fannie Merritt Farmer"
books.loc[1964, 'author'] = "Scott Cunningham"
books.loc[1965, 'author'] = "Auguste Escoffier"
books.loc[1968, 'author'] = "The Culinary Institute Of America"
books.loc[1974, 'author'] = "Wayne Gisslen"
books.loc[1980, 'author'] = "Hugo Ziemann, F. L. Gillette"

# %%
# title check for the full data set (in blocks) to clean any typos or anything that is not consistent with the original title of the book
books.loc[1900:2003, ['title', 'author']]
# Out:
#                                                                        title  \
# book_id
# 1900                                                     Fitness For Dummies
# 1901                                                   Tom'S Midnight Garden
# 1902                                                     Thinking In Systems
# 1903                                               The Power Of Productivity
# 1904                                                          How Not To Die
# 1905                                             How To Make Money In Stocks
# 1906                                                               Bad Blood
# 1907                                                        Techno-Feudalism
# 1908                                         Principles Of Political Economy
# 1909                                                        Expecting Better
# 1910     The Economic Consequences Of The Peace (Twentieth-Century Classics)
# ...

# %%
# cleaning the title column
# straight apostrophe
books['title'] = books['title'].str.replace("'S", "'s", regex=False)

# curly apostrophe
books['title'] = books['title'].str.replace("\u2019S", "\u2019s", regex=False)

# %%
# manual imputting on titles for corrections
books.loc[268, 'title'] = "We Need To Talk About Kevin"
books.loc[269, 'title'] = "The Black Dahlia"
books.loc[283, 'title'] = "In Cold Blood"
books.loc[461, 'title'] = "Salem's Lot"
books.loc[665, 'title'] = "I'll Give You The Sun"
books.loc[717, 'title'] = "To All The Boys I've Loved Before (To All The Boys I've Loved Before, #1)"
books.loc[719, 'title'] = "Demian: Die Geschichte Von Emil Sinclairs Jugend"
books.loc[729, 'title'] = "Being A Witch, And Other Things I Didn't Ask For"
books.loc[890, 'title'] = "I'd Tell You I Love You, But Then I'd Have To Kill You (Gallagher Girls, #1)"
books.loc[914, 'title'] = "It Ain't Me, Babe (Hades Hangmen, #1)"
books.loc[948, 'title'] = "I'm Glad You're Dead: Preternatural Chronicles Book 1"
books.loc[1029, 'title'] = "Can't Hurt Me"
books.loc[1089, 'title'] = "Don't Panic"
books.loc[1202, 'title'] = "21 Lessons For The 21st Century"
books.loc[1320, 'title'] = "Atlas Shrugged"
books.loc[1359, 'title'] = "Don't Believe Everything You Think"
books.loc[1377, 'title'] = "You're Too Good To Feel This Bad"
books.loc[1382, 'title'] = "3AM Questions"
books.loc[1399, 'title'] = "It Didn't Start With You"
books.loc[1443, 'title'] = "The Old Patagonian Express"
books.loc[1512, 'title'] = "Animal Farm And Nineteen Eighty-Four"
books.loc[1569, 'title'] = "It Can't Happen Here"
books.loc[1587, 'title'] = "Why We're Polarized"
books.loc[1595, 'title'] = "Henry IV, Part 2"
books.loc[1623, 'title'] = "Nature, Man And Woman"
books.loc[1743, 'title'] = "The Science Fiction Hall Of Fame: Volume One"
books.loc[1751, 'title'] = "The Hitchhiker's Guide To The Galaxy: The Complete Collection"
books.loc[1785, 'title'] = "The Poems Of Emily Dickinson: Volume II"
books.loc[1910, 'title'] = "The Economic Consequences Of The Peace"
books.loc[1938, 'title'] = "L'Imagination Sociologique"
books.loc[2003, 'title'] = "The Deal / The Mistake / The Score / The Goal / The Legacy"

# %%
pd.reset_option('display.max_colwidth')
pd.reset_option('display.max_rows')

# %%
# extracting all size patterns from cover URLs (goodreads)
sizes = books['cover_img_url'].dropna().str.extractall(r'(_S[XY]\d+_)')
print(sizes[0].value_counts())
# Out:
# 0
# _SY75_    799
# _SX50_    205
# Name: count, dtype: int64

# %%
# correcting the links with SY and SX size patterns to the larger SY475 and SX318 patterns
books['cover_img_url'] = books['cover_img_url'].str.replace('_SY75_', '_SY475_', regex=False)
books['cover_img_url'] = books['cover_img_url'].str.replace('_SX50_', '_SX318_', regex=False)

# %%
# checking cover URLs that are not from goodreads
non_goodreads = books[~books['cover_img_url'].str.contains('goodreads', na=False, case=False)]
print(non_goodreads[['title', 'cover_img_url']])
# Out:
#                                                      title  \
# book_id
# 1004                                         Wings Of Fire
# 1005                 The Diary Of A Young Girl- Anne Frank
# 1006                               Autobiography Of A Yogi
# 1007                                  I'M Glad My Mom Died
# 1008                                      Reminders Of Him
# ...                                                    ...
# 1999                                     The Art Of Eating
# 2000                                The Fireside Cook Book
# 2001                             The Little House Cookbook
# 2002                            The Silver Palate Cookbook
# 2003     The Deal / The Mistake / The Score / The Goal ...
#
#                                              cover_img_url
# book_id
# 1004     https://covers.openlibrary.org/b/id/9153819-L.jpg
# 1005     https://covers.openlibrary.org/b/id/13526331-L...
# ...

# %%
# check size suffixes from open library cover URLs
ol_books = books[books['cover_img_url'].str.contains('openlibrary', na=False, case=False)]
sizes_ol = ol_books['cover_img_url'].dropna().str.extractall(r'(-[SML]\.jpg)')
print(sizes_ol[0].value_counts())
# Out:
# 0
# -L.jpg    996
# Name: count, dtype: int64

# %%
# checking the genre column for standardizing names
books['genres_clean'].str.split(', ').explode().str.strip().unique().tolist()
# Out:
# ['Young Adult',
#  'Dystopia',
#  'Fiction',
#  'Fantasy',
#  'Science Fiction',
#  'Romance',
#  'Adventure',
#  'Classics',
#  'Historical Fiction',
#  'History',
#  'Literature',
#  'Childrens',
#  'Politics',
#  'Christian',
#  'Contemporary',
#  'Horror',
#  'Gothic',
#  'Psychology',
#  'Philosophy',
#  'Mystery',
#  'Thriller',
#  'Self Help',
#  'Drama',
#  'Humor',
#  'Comedy',
#  'Animals',
#  'Magical Realism',
#  'Time Travel',
#  'Crime',
#  'Women Studies',
#  'Lgbt',
#  'Queer',
#  'Religion',
#  'Nonfiction',
#  'Biography',
#  'Africa',
#  'Travel',
#  'Theatre',
#  '19Th Century',
#  '20Th Century',
#  'Enemies To Lovers',
#  'Art',
#  'New Adult',
#  'Love',
#  'Science',
#  'Human Sciences',
#  'Business',
#  'Education',
#  'Dark',
#  'Health',
#  'Social Life And Customs',
#  'Crimes Against',
#  'Journeys',
#  'Criminals',
#  'Law',
#  'Gardening',
#  'Histoire',
#  'Civilization',
#  'Economic Conditions',
#  'Early Works To 1800',
#  'Conduct Of Life',
# ...

# %%
# standardizing the century genre names
books['genres_clean'] = books['genres_clean'].str.replace("Children'S Poetry", "Children's Poetry", regex=False)
books['genres_clean'] = books['genres_clean'].str.replace('19Th Century', '19th Century', regex=False)
books['genres_clean'] = books['genres_clean'].str.replace('20Th Century', '20th Century', regex=False)
books['genres_clean'] = books['genres_clean'].str.replace('Lgbt', 'LGBT', regex=False)

# %%
# checking if standarization worked
books['genres_clean'].str.split(', ').explode().str.strip().unique().tolist()
# Out:
# ['Young Adult',
#  'Dystopia',
#  'Fiction',
#  'Fantasy',
#  'Science Fiction',
#  'Romance',
#  'Adventure',
#  'Classics',
#  'Historical Fiction',
#  'History',
#  'Literature',
#  'Childrens',
#  'Politics',
#  'Christian',
#  'Contemporary',
#  'Horror',
#  'Gothic',
#  'Psychology',
#  'Philosophy',
#  'Mystery',
#  'Thriller',
#  'Self Help',
#  'Drama',
#  'Humor',
#  'Comedy',
#  'Animals',
#  'Magical Realism',
#  'Time Travel',
#  'Crime',
#  'Women Studies',
#  'LGBT',
#  'Queer',
#  'Religion',
#  'Nonfiction',
#  'Biography',
#  'Africa',
#  'Travel',
#  'Theatre',
#  '19th Century',
#  '20th Century',
#  'Enemies To Lovers',
#  'Art',
#  'New Adult',
#  'Love',
#  'Science',
#  'Human Sciences',
#  'Business',
#  'Education',
#  'Dark',
#  'Health',
#  'Social Life And Customs',
#  'Crimes Against',
#  'Journeys',
#  'Criminals',
#  'Law',
#  'Gardening',
#  'Histoire',
#  'Civilization',
#  'Economic Conditions',
#  'Early Works To 1800',
#  'Conduct Of Life',
# ...

# %% [markdown]
# # 04. Exporting beautiful dataframe

# %%
books.to_csv('../01. Data/books_streamlit.csv', index=True)
